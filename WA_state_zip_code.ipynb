# %% [markdown]
# <a href="https://colab.research.google.com/github/haticenuralan/Data_Cleaning_WA/blob/main/WA_state_zip_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df= pd.read_excel("/content/sample_data/uszips.xlsx")

df.head(100)
# Out:
#     zip       lat       lng          city state_id      state_name  zcta  \
# 0   601  18.18027 -66.75266      Adjuntas       PR     Puerto Rico  True
# 1   602  18.36075 -67.17541        Aguada       PR     Puerto Rico  True
# 2   603  18.45744 -67.12225     Aguadilla       PR     Puerto Rico  True
# 3   606  18.16585 -66.93716       Maricao       PR     Puerto Rico  True
# 4   610  18.29110 -67.12243        Anasco       PR     Puerto Rico  True
# ..  ...       ...       ...           ...      ...             ...   ...
# 95  840  17.72649 -64.84717  Frederiksted       VI  Virgin Islands  True
# 96  850  17.72763 -64.79122     Kingshill       VI  Virgin Islands  True
# 97  851  17.74757 -64.78737     Kingshill       VI  Virgin Islands  True
# 98  901  18.46478 -66.10277      San Juan       PR     Puerto Rico  True
# 99  906  18.46446 -66.09499      San Juan       PR     Puerto Rico  True
#
#     parent_zcta  population  density  county_fips county_name  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33788 entries, 0 to 33787
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   zip               33788 non-null  int64
#  1   lat               33788 non-null  float64
#  2   lng               33788 non-null  float64
#  3   city              33788 non-null  object
#  4   state_id          33788 non-null  object
#  5   state_name        33788 non-null  object
#  6   zcta              33788 non-null  bool
#  7   parent_zcta       0 non-null      float64
#  8   population        33771 non-null  float64
#  9   density           33771 non-null  float64
#  10  county_fips       33788 non-null  int64
#  11  county_name       33788 non-null  object
#  12  county_weights    33788 non-null  object
#  13  county_names_all  33788 non-null  object
#  14  county_fips_all   33788 non-null  object
#  15  imprecise         33788 non-null  bool
# ...

# %%
df.isnull().sum()
# Out:
# zip                  0
# lat                  0
# lng                  0
# city                 0
# state_id             0
# state_name           0
# zcta                 0
# population          17
# density             17
# county_fips          0
# county_name          0
# county_weights       0
# county_names_all     0
# county_fips_all      0
# imprecise            0
# military             0
# timezone             0
# dtype: int64

# %%
#df.drop('parent_zcta', axis=1, inplace=True)
df.drop('zcta', axis=1, inplace=True)
df.drop('imprecise', axis=1, inplace=True)
df.drop('military', axis=1, inplace=True)

# %%
df.head()
# Out:
#    zip       lat       lng       city state_id   state_name  population  \
# 0  601  18.18027 -66.75266   Adjuntas       PR  Puerto Rico     17126.0
# 1  602  18.36075 -67.17541     Aguada       PR  Puerto Rico     37895.0
# 2  603  18.45744 -67.12225  Aguadilla       PR  Puerto Rico     49136.0
# 3  606  18.16585 -66.93716    Maricao       PR  Puerto Rico      5751.0
# 4  610  18.29110 -67.12243     Anasco       PR  Puerto Rico     26153.0
#
#    density  county_fips county_name  \
# 0    102.6        72001    Adjuntas
# 1    482.5        72003      Aguada
# 2    552.4        72005   Aguadilla
# 3     50.1        72093     Maricao
# 4    272.1        72011      Añasco
#
#                                       county_weights  \
# 0                    {"72001": 98.73, "72141": 1.27}
# 1                                     {"72003": 100}
# 2                    {"72005": 99.76, "72099": 0.24}
# 3    {"72093": 82.27, "72153": 11.66, "72121": 6.06}
# ...

# %%
df['state_id'].unique()
# Out:
# array(['PR', 'VI', 'MA', 'RI', 'NH', 'ME', 'VT', 'CT', 'NY', 'NJ', 'PA',
#        'DE', 'DC', 'VA', 'MD', 'WV', 'NC', 'SC', 'GA', 'FL', 'AL', 'TN',
#        'MS', 'KY', 'OH', 'IN', 'MI', 'IA', 'WI', 'MN', 'SD', 'ND', 'MT',
#        'IL', 'MO', 'KS', 'NE', 'LA', 'AR', 'OK', 'TX', 'CO', 'WY', 'ID',
#        'UT', 'AZ', 'NM', 'NV', 'CA', 'HI', 'AS', 'GU', 'MP', 'OR', 'WA',
#        'AK'], dtype=object)

# %%
df[df['state_id'] == 'WA']
# Out:
#          zip       lat        lng         city state_id  state_name  \
# 32938  98001  47.30919 -122.26426       Auburn       WA  Washington
# 32939  98002  47.30820 -122.21567       Auburn       WA  Washington
# 32940  98003  47.30596 -122.31465  Federal Way       WA  Washington
# 32941  98004  47.61865 -122.20548     Bellevue       WA  Washington
# 32942  98005  47.61494 -122.16814     Bellevue       WA  Washington
# ...      ...       ...        ...          ...      ...         ...
# 33538  99363  46.04821 -118.89575      Wallula       WA  Washington
# 33539  99371  46.79144 -118.30614    Washtucna       WA  Washington
# 33540  99401  46.09041 -117.27336      Anatone       WA  Washington
# 33541  99402  46.18680 -117.14922       Asotin       WA  Washington
# 33542  99403  46.38114 -117.25974    Clarkston       WA  Washington
#
#        population  density  county_fips  county_name  \
# 32938     35297.0    731.3        53033         King
# ...

# %%
wa_data = df[df['state_id'] == 'WA']
wa_data_missing = wa_data.isnull().sum()
print(wa_data_missing)
# Out:
# zip                 0
# lat                 0
# lng                 0
# city                0
# state_id            0
# state_name          0
# population          0
# density             0
# county_fips         0
# county_name         0
# county_weights      0
# county_names_all    0
# county_fips_all     0
# timezone            0
# dtype: int64

# %%
wa_data.to_excel('wa_data.xlsx', index=False)

# %%
from google.colab import files

files.download('wa_data.xlsx')
